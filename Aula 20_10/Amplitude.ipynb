# %%
# Importa a biblioteca pandas, que é usada para manipulação e análise de dados
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados_array = np.array([5, 8, 12, 15, 20, 25, 30])

minimo = np.min(dados_array)
maximo = np.max(dados_array)
amplitude = maximo - minimo

print(f'Máximo: {maximo}\nMínimo: {minimo}\nAplitude: {amplitude}')
# Out:
# Máximo: 30
# Mínimo: 5
# Aplitude: 25

# %%
import random

valores_vendidos =  [random.randint(1000, 1000000) for i in vendedores]


valores_vendidos. append(3000000)
vendedores.append("Trunks")

dados_vendas = {'Vendedores': vendedores,
                'valores_vendidos': valores_vendidos}


df = pd.DataFrame(dados_vendas)
df.sort_values(by='valores_vendidos', ascending=False, inplace= True)
df
# Out:
#          Vendedores  valores_vendidos
# 30           Trunks           3000000
# 9    camila_barbosa            982949
# 10     joao_pereira            974609
# 23      taylor_lima            927082
# 7       bruna_costa            883688
# 24     jordan_souza            879022
# 19  daniel_monteiro            870355
# 28     jamie_ferraz            861130
# 27    morgan_barros            859707
# 4    patricia_rocha            817509
# 5       renata_lima            774349
# 0         ana_silva            750003
# 17   gustavo_torres            745144
# 16  tiago_rodrigues            722773
# 3     carla_martins            614720
# 22      sam_martins            587639
# 1    maria_oliveira            554091
# 15      andre_gomes            549362
# 14     lucas_mendes            547108
# 8       paula_ramos            543517
# 29      robin_pinto            533086
# 21   chris_oliveira            480684
# 2    juliana_santos            467253
# 25     casey_santos            436463
# 13  rafael_silveira            319246
# 6    aline_ferreira            188850
# 11      pedro_souza            171821
# 18    felipe_castro            164578
# 20       alex_costa            148472
# 26       drew_rocha            135841
# 12   marcos_almeida            119201

# %%
valores_vendidos_array = np.array(df['valores_vendidos'])

# %%
plt.figure(figsize=(15, 10))
plt.boxplot(valores_vendidos_array, vert= False, showmeans= True)
plt.title('Boxplot')
plt.show()
