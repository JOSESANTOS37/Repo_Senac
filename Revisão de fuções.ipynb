# %%
def saudacao():
    print('Bem vindo ao Senac')

# %%
saudacao
# Out:
# <function __main__.saudacao()>

# %%
def multiplicacao(a,b):
    resultado = a * b
    print(f'O resultado de {a} * {b} é {resultado}')

# %%
multiplicacao(5,3)
# Out:
# O resultado de 5 * 3 é 15

# %%
def multiplicacao(a,b):
    resultado = a * b
    return resultado

# %%
multiplicacao(5,3)
# Out:
# 15

# %%
def situacao_aluno(lista):
    media = sum(lista) /len (lista)

    if media >= 7:
        print ('Aprovado')

    elif meia >=5 and media <7:
    
        print ('Recuperação')
    
    else:
        print('Reprovado')

# %%
joao = [8,9,7,7.5]
situacao_aluno(joao)
# Out:
# Aprovado
